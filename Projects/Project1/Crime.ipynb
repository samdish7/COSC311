# %%
# import stuff
import pandas as p
import numpy as n
import seaborn as s

# %% [markdown]
# ## Data Set 3; Crime in Baltimore
#
# This is the data set containing the selling price predictions of 14k 2nd hand cars.
#
# [csv link](https://www.kaggle.com/sohier/crime-in-baltimore)
#
# ### Useful Stats:
# - Size of set ~> 276,530
# - Columns ~> 15

# %%
crime = p.read_csv('data/crime.csv', header = None, skipinitialspace = True, encoding = 'latin-1', low_memory = False)
len(crime)
# Out:
# 276530

# %%
crime
# Out:
#                 0          1          2                      3   \
# 0        CrimeDate  CrimeTime  CrimeCode               Location
# 1       09/02/2017   23:30:00        3JK        4200 AUDREY AVE
# 2       09/02/2017   23:00:00         7A      800 NEWINGTON AVE
# 3       09/02/2017   22:53:00         9S          600 RADNOR AV
# 4       09/02/2017   22:50:00         4C         1800 RAMSAY ST
# ...            ...        ...        ...                    ...
# 276525  01/01/2012   00:00:00         6J           1400 JOH AVE
# 276526  01/01/2012   00:00:00         6J       5500 SINCLAIR LN
# 276527  01/01/2012   00:00:00         6E  400 N PATTERSON PK AV
# 276528  01/01/2012   00:00:00         5A        5800 LILLYAN AV
# 276529  01/01/2012   00:00:00         5A      1900 GRINNALDS AV
#
#                          4               5        6     7             8   \
# 0               Description  Inside/Outside   Weapon  Post      District
# 1       ROBBERY - RESIDENCE               I    KNIFE   913      SOUTHERN
# 2                AUTO THEFT               O      NaN   133       CENTRAL
# 3                  SHOOTING         Outside  FIREARM   524      NORTHERN
# 4              AGG. ASSAULT               I    OTHER   934      SOUTHERN
# ...                     ...             ...      ...   ...           ...
# 276525              LARCENY               I      NaN   832  SOUTHWESTERN
# 276526              LARCENY               O      NaN   444  NORTHEASTERN
# 276527              LARCENY               O      NaN   321       EASTERN
# 276528             BURGLARY               I      NaN   425  NORTHEASTERN
# 276529             BURGLARY               I      NaN   831  SOUTHWESTERN
#
#                       9          10        11  \
# 0           Neighborhood  Longitude  Latitude
# 1               Brooklyn  -76.60541  39.22951
# 2         Reservoir Hill  -76.63217   39.3136
# 3         Winston-Govans  -76.60697  39.34768
# 4       Carrollton Ridge  -76.64526  39.28315
# ...                  ...        ...       ...
# 276525       Violetville  -76.67195  39.26132
# 276526         Frankford  -76.53829  39.32493
# 276527              CARE  -76.58497  39.29573
# 276528    Glenham-Belhar  -76.54578  39.34701
# 276529      Morrell Park  -76.65094  39.26698
#
#                                      12          13               14
# 0                            Location 1     Premise  Total Incidents
# 1       (39.2295100000, -76.6054100000)  ROW/TOWNHO                1
# 2       (39.3136000000, -76.6321700000)      STREET                1
# 3       (39.3476800000, -76.6069700000)      Street                1
# 4       (39.2831500000, -76.6452600000)  ROW/TOWNHO                1
# ...                                 ...         ...              ...
# 276525  (39.2613200000, -76.6719500000)  OTHER - IN                1
# 276526  (39.3249300000, -76.5382900000)  OTHER - OU                1
# 276527  (39.2957300000, -76.5849700000)      STREET                1
# 276528  (39.3470100000, -76.5457800000)  APT. LOCKE                1
# 276529  (39.2669800000, -76.6509400000)  ROW/TOWNHO                1
#
# [276530 rows x 15 columns]
